# %% [markdown]
# <h1> Netflix records </h1>

# %%
import pandas as pd

# Specify the file path
file_path = "C:/Users/Bubi/Desktop/netflix.csv"

# Read the file using pandas
df = pd.read_csv(file_path)

# Display the DataFrame
print(df)
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df.head(5)
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
df.tail(5)
# Out:
#      show_id     type        title         director  \
# 8802   s8803    Movie       Zodiac    David Fincher
# 8803   s8804  TV Show  Zombie Dumb              NaN
# 8804   s8805    Movie   Zombieland  Ruben Fleischer
# 8805   s8806    Movie         Zoom     Peter Hewitt
# 8806   s8807    Movie       Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# 8803                                                NaN            NaN
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#              date_added  release_year rating   duration  \
# 8802  November 20, 2019          2007      R    158 min
# 8803       July 1, 2019          2018  TV-Y7  2 Seasons
# ...

# %%
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
df['title'].head(5)
# Out:
# 0     Dick Johnson Is Dead
# 1            Blood & Water
# 2                Ganglands
# 3    Jailbirds New Orleans
# 4             Kota Factory
# Name: title, dtype: object

# %%
df['title'][0:5]
# Out:
# 0     Dick Johnson Is Dead
# 1            Blood & Water
# 2                Ganglands
# 3    Jailbirds New Orleans
# 4             Kota Factory
# Name: title, dtype: object

# %%
df[['type','title', 'country']]
# Out:
#          type                  title        country
# 0       Movie   Dick Johnson Is Dead  United States
# 1     TV Show          Blood & Water   South Africa
# 2     TV Show              Ganglands            NaN
# 3     TV Show  Jailbirds New Orleans            NaN
# 4     TV Show           Kota Factory          India
# ...       ...                    ...            ...
# 8802    Movie                 Zodiac  United States
# 8803  TV Show            Zombie Dumb            NaN
# 8804    Movie             Zombieland  United States
# 8805    Movie                   Zoom  United States
# 8806    Movie                 Zubaan          India
#
# [8807 rows x 3 columns]

# %%
df.iloc[0:4]
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
# 3  September 24, 2021          2021  TV-MA   1 Season
#
# ...

# %%
df.loc[df['cast'] == "NaN"]
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description]
# Index: []

# %%
df.describe()
# Out:
#        release_year
# count   8807.000000
# mean    2014.180198
# std        8.819312
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000

# %%
df.sort_values(['release_year', 'cast'], ascending=False)[0:5]
# Out:
#      show_id     type             title          director  \
# 109     s110  TV Show  La casa de papel               NaN
# 1212   s1213    Movie       Paper Lives         Can Ulkay
# 1260   s1261    Movie   Crazy About Her  Dani de la Orden
# 1375   s1376  TV Show           BONDING               NaN
# 222     s223  TV Show         Clickbait     Brad Anderson
#
#                                                    cast        country  \
# 109   Úrsula Corberó, Itziar Ituño, Álvaro Morte, Pa...          Spain
# 1212  Çağatay Ulusoy, Emir Ali Doğrul, Ersin Arıcı, ...         Turkey
# 1260  Álvaro Cervantes, Susana Abaitua, Luis Zahera,...          Spain
# 1375  Zoe Levin, Brendan Scannell, Micah Stock, Theo...  United States
# 222   Zoe Kazan, Betty Gabriel, Adrian Grenier, Phoe...            NaN
#
#              date_added  release_year rating   duration  \
# 109   September 3, 2021          2021  TV-MA  5 Seasons
# 1212     March 12, 2021          2021  TV-MA     97 min
# ...

# %%
df['Short info'] = df['title'] + "-" + df["duration"]
df[0:10]
# Out:
#   show_id     type                             title  \
# 0      s1    Movie              Dick Johnson Is Dead
# 1      s2  TV Show                     Blood & Water
# 2      s3  TV Show                         Ganglands
# 3      s4  TV Show             Jailbirds New Orleans
# 4      s5  TV Show                      Kota Factory
# 5      s6  TV Show                     Midnight Mass
# 6      s7    Movie  My Little Pony: A New Generation
# 7      s8    Movie                           Sankofa
# 8      s9  TV Show     The Great British Baking Show
# 9     s10    Movie                      The Starling
#
#                         director  \
# 0                Kirsten Johnson
# 1                            NaN
# 2                Julien Leclercq
# 3                            NaN
# 4                            NaN
# 5                  Mike Flanagan
# 6  Robert Cullen, José Luis Ucha
# 7                   Haile Gerima
# 8                Andy Devonshire
# 9                 Theodore Melfi
#
# ...

# %%
df.head(5)
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year   duration  \
# 0  September 25, 2021          2020     90 min
# 1  September 24, 2021          2021  2 Seasons
# 2  September 24, 2021          2021   1 Season
# ...

# %%
df.head(10)
# Out:
#   show_id     type                             title  \
# 0      s1    Movie              Dick Johnson Is Dead
# 1      s2  TV Show                     Blood & Water
# 2      s3  TV Show                         Ganglands
# 3      s4  TV Show             Jailbirds New Orleans
# 4      s5  TV Show                      Kota Factory
# 5      s6  TV Show                     Midnight Mass
# 6      s7    Movie  My Little Pony: A New Generation
# 7      s8    Movie                           Sankofa
# 8      s9  TV Show     The Great British Baking Show
# 9     s10    Movie                      The Starling
#
#                         director  \
# 0                Kirsten Johnson
# 1                            NaN
# 2                Julien Leclercq
# 3                            NaN
# 4                            NaN
# 5                  Mike Flanagan
# 6  Robert Cullen, José Luis Ucha
# 7                   Haile Gerima
# 8                Andy Devonshire
# 9                 Theodore Melfi
#
# ...

# %%
if 'show_id' in df.columns:
    df = df.drop(['show_id'], axis=1)
    print("Column 'show_id' dropped successfully.")
else:
    print("Column 'show_id' does not exist in the DataFrame.")
# Out:
# Column 'show_id' dropped successfully.

# %%
df
# Out:
#       type                  title         director  \
# 0    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1  TV Show          Blood & Water              NaN
# 2  TV Show              Ganglands  Julien Leclercq
# 3  TV Show  Jailbirds New Orleans              NaN
# 4  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year   duration  \
# 0  September 25, 2021          2020     90 min
# 1  September 24, 2021          2021  2 Seasons
# 2  September 24, 2021          2021   1 Season
# 3  September 24, 2021          2021   1 Season
# ...

# %%
df.loc[(df['release_year'] > 2020)]
# Out:
#       type                  title         director  \
# 1  TV Show          Blood & Water              NaN
# 2  TV Show              Ganglands  Julien Leclercq
# 3  TV Show  Jailbirds New Orleans              NaN
# 4  TV Show           Kota Factory              NaN
#
#                                                 cast       country  \
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...  South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...           NaN
# 3                                                NaN           NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...         India
#
#            date_added  release_year   duration  \
# 1  September 24, 2021          2021  2 Seasons
# 2  September 24, 2021          2021   1 Season
# 3  September 24, 2021          2021   1 Season
# 4  September 24, 2021          2021  2 Seasons
#
#                                            listed_in  \
# 1    International TV Shows, TV Dramas, TV Mysteries
# ...

# %%
df.loc[df["title"].str.contains('ta|ew', regex=True)]
# Out:
#       type                  title director  \
# 3  TV Show  Jailbirds New Orleans      NaN
# 4  TV Show           Kota Factory      NaN
#
#                                                 cast country  \
# 3                                                NaN     NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...   India
#
#            date_added  release_year   duration  \
# 3  September 24, 2021          2021   1 Season
# 4  September 24, 2021          2021  2 Seasons
#
#                                            listed_in  \
# 3                             Docuseries, Reality TV
# 4  International TV Shows, Romantic TV Shows, TV ...
#
#                                          description  \
# 3  Feuds, flirtations and toilet talk go down amo...
# 4  In a city of coaching centers known to train I...
#
#                                                Total  \
# 3                                                NaN
# 4  IndiaInternational TV Shows, Romantic TV Shows...
#
# ...
